# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as mvn
from numba import jit, autojit
import time

# %%
def tile_image(tile_rows, tile_cols, row_overlap, col_overlap, im):
    im_rows = im.shape[0]
    im_cols = im.shape[1]
    im_channels = im.shape[2]
    
    row_stride = (tile_rows - row_overlap)
    n_tiles_row = int(np.ceil((im_rows - tile_rows)/row_stride) + 1)
    im_padded_rows = (n_tiles_row - 1)*row_stride + tile_rows
    col_stride = (tile_cols - col_overlap)
    n_tiles_col = int(np.ceil((im_cols - tile_cols)/col_stride) + 1)
    im_padded_cols = (n_tiles_col - 1)*col_stride + tile_cols
    
    pad_rows = im_padded_rows - im_rows
    pad_cols = im_padded_cols - im_cols
    im_padded = np.pad(im, ((0,pad_rows),(0,pad_cols),(0,0)), 'wrap')
            
    tiles = [im_padded[i*row_stride:i*row_stride+tile_rows,j*col_stride:j*col_stride+tile_cols,:] for i in range(n_tiles_row) for j in range (n_tiles_col)]
    return tiles, n_tiles_row, n_tiles_col

# %%
@autojit
def em_gmm_orig(xs, pis, mus, sigmas, tol=0.001, max_iter=100):
    n, p = xs.shape
    k = len(pis)
    print(n, p, k)
    ll_old = 0
    for i in range(max_iter):
        start_time = time.perf_counter()
        exp_A = []
        exp_B = []
        ll_new = 0

        # E-step
        ws = e_step(k, n, xs, pis, mus, sigmas)
        # M-step
        pis, mus, sigmas = m_step(k, n, p, mus, ws, xs, sigmas)

        # update complete log likelihoood
        ll_new = log_likelihood(k, n, pis, mus, sigmas, xs)

        end_time = time.perf_counter()
        print('Iteration: %d, Elapse time: %.2f sec' % (i, end_time - start_time))
        
#         if np.abs(ll_new - ll_old) < tol:
#             break
        ll_old = ll_new


    return pis, mus, sigmas

# %%
@autojit
def e_step(k, n, xs, pis, mus, sigmas):
    ws = np.zeros((k, n))
    for j in range(k):
        for i in range(n):
            ys = np.reshape(xs[i]- mus[j], (3,1))
            zs = -np.dot(ys.T, ys)/2
#             print(ys)
#             print(zs)
#             print(pis[j])
            ws[j, i] = pis[j] * np.exp(zs)
    ws /= ws.sum(0)
    return ws

# %%
@autojit
def m_step(k, n, p, mus, ws, xs, sigmas):
    pis = np.mean(ws, axis = 1)
    mus = np.zeros((k, p))
    for j in range(k):
        mus[j] = np.dot(xs, ws[j, :])
        mus[j] /= ws[j, :].sum()
        
#     sigmas = np.zeros((k, p, p))
#     for j in range(k):
#         for i in range(n):
#             ys = np.reshape(xs[i]- mus[j], (3,1))
#             sigmas[j] += ws[j, i] * np.dot(ys, ys.T)
#         sigmas[j] /= ws[j,:].sum()
    
    return pis, mus, sigmas

# %%
@autojit
def log_likelihood(k, n, pis, mus, sigmas, xs):
    ll_new = 0.0
    for i in range(n):
        s = 0
        for j in range(k):
            ys = np.reshape(xs[i]- mus[j], (3,1))
            zs = -np.dot(ys.T, ys)/2
            s += pis[j] * np.exp(zs)
        ll_new += np.log(s)
    return ll_new

# %%
import imageio
im = imageio.imread('tree.jpg')
n, m, c = im.shape
plt.imshow(im)
plt.show()
tile_row = int(np.ceil(n/9))
tile_col = int(np.ceil(m/9))
dim = tile_row*tile_col
tiles, n_tiles_row, n_tiles_col = tile_image(tile_row, tile_col, 0, 0, im)
im = tiles[23]
plt.imshow(im)
plt.show()

# %%
k = 20
pis = np.random.random(k)
pis /= pis.sum()
mus = np.random.random((k,c))
sigmas = np.array([np.eye(c)]*k)
xs = im/255
n, m, c = xs.shape
xs = xs.reshape(n*m, c)
print(xs.shape)
print(pis)
print(mus)
# Out:
# (3960, 3)
# [0.03293706 0.05142685 0.05231399 0.00267456 0.03071099 0.09063463
#  0.02786627 0.00774995 0.02656662 0.07718425 0.04845738 0.05533046
#  0.08733923 0.10057742 0.08268479 0.00582    0.05018686 0.04232149
#  0.10939888 0.01781831]
# [[0.41148371 0.92932084 0.12496903]
#  [0.37780387 0.78942768 0.97827988]
#  [0.53642371 0.34684894 0.51011817]
#  [0.99397869 0.02727183 0.43260702]
#  [0.72233111 0.12904286 0.44432113]
#  [0.33088505 0.21484152 0.96612329]
#  [0.89088323 0.19230128 0.17834192]
#  [0.89380157 0.43084399 0.44142863]
#  [0.98751574 0.61176827 0.24405502]
#  [0.67777294 0.62999636 0.07336897]
#  [0.19173956 0.92972044 0.33105663]
#  [0.27332582 0.85877125 0.16705104]
#  [0.33181525 0.1142758  0.94266329]
#  [0.1721326  0.93925186 0.45111881]
#  [0.02333781 0.53122789 0.92493565]
#  [0.75516197 0.40224865 0.81010845]
#  [0.28810064 0.07794243 0.46436933]
#  [0.50678109 0.43003274 0.57535059]
#  [0.91823949 0.98813395 0.2638031 ]
# ...

# %%
# %%time
pis1, mus1, sigmas1 = em_gmm_orig(xs, pis, mus, sigmas)
# Out:
# 3960 3 20
# Iteration: 0, Elapse time: 1.79 sec
# Iteration: 1, Elapse time: 0.99 sec
# Iteration: 2, Elapse time: 0.98 sec
# Iteration: 3, Elapse time: 0.97 sec
# Iteration: 4, Elapse time: 0.97 sec
# Iteration: 5, Elapse time: 0.97 sec
# Iteration: 6, Elapse time: 1.00 sec
# Iteration: 7, Elapse time: 0.98 sec
# Iteration: 8, Elapse time: 0.98 sec
# Iteration: 9, Elapse time: 0.99 sec
# Iteration: 10, Elapse time: 1.01 sec
# Iteration: 11, Elapse time: 1.00 sec
# Iteration: 12, Elapse time: 0.99 sec
# Iteration: 13, Elapse time: 1.01 sec
# Iteration: 14, Elapse time: 1.00 sec
# Iteration: 15, Elapse time: 0.99 sec
# Iteration: 16, Elapse time: 1.01 sec
# Iteration: 17, Elapse time: 0.99 sec
# Iteration: 18, Elapse time: 1.01 sec
# Iteration: 19, Elapse time: 0.99 sec
# Iteration: 20, Elapse time: 1.01 sec
# Iteration: 21, Elapse time: 1.03 sec
# Iteration: 22, Elapse time: 1.02 sec
# Iteration: 23, Elapse time: 1.00 sec
# Iteration: 24, Elapse time: 1.01 sec
# ...

# %%
print(pis1)
print(mus1)
# Out:
# [0.03320906 0.05403705 0.05822563 0.00246498 0.03127607 0.08390926
#  0.02698189 0.00883025 0.02925026 0.08170286 0.04788504 0.05463343
#  0.07732903 0.10043975 0.0728598  0.00656366 0.04522011 0.04816893
#  0.11861051 0.01840244]
# [[0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]
#  [0.72596356 0.69862745 0.58455635]]

# %%
print(pis1)
print(mus1)
# Out:
# [0.12134536 0.04313466 0.15925094 0.16513808 0.06762007 0.22401785
#  0.084647   0.03024383 0.0258003  0.07880191]
# [[0.80691775 0.68363028 0.49624653]
#  [0.75078243 0.67909172 0.53819845]
#  [0.55833197 0.57575282 0.54309165]
#  [0.65403119 0.76707216 0.74130005]
#  [0.66892901 0.72939354 0.6754515 ]
#  [0.85679538 0.73923128 0.52513951]
#  [0.76571111 0.67193446 0.50854103]
#  [0.65650413 0.63290101 0.56878514]
#  [0.79839922 0.74998458 0.63936288]
#  [0.71448736 0.73255378 0.66191586]]

# %%
im_new = np.zeros((n*m, c))
xs = xs.reshape(n*m, c)
for i in range(n*m):
    maxlikelihood = 0
    label = 0
    for j in range(k):
        likelihood = mvn(mus[j], sigmas[j]).pdf(xs[i])
        if likelihood > maxlikelihood:
            maxlikelihood = likelihood
            label = j
    im_new[i] = mus1[label]
im_new = im_new.reshape(n, m, c)
plt.imshow(im_new)
plt.show()
xs = xs.reshape(n, m, c)
plt.imshow(xs)
plt.show()

# %%
k = 20
pis = np.random.random(k)
pis /= pis.sum()
mus = np.random.random((k,c))
sigmas = np.array([np.eye(c)]*k)
xs = im/255
n, m, c = xs.shape
xs = xs.reshape(n*m, c)
# print(xs.shape)
# print(pis, mus, sigmas)

# %%
# %%time
pis1, mus1, sigmas1 = em_gmm_orig(xs, pis, mus, sigmas)

# %%
im_new = np.zeros((n*m, c))
xs = xs.reshape(n*m, c)
for i in range(n*m):
    maxlikelihood = 0
    label = 0
    for j in range(k):
        likelihood = mvn(mus[j], sigmas[j]).pdf(xs[i])
        if likelihood > maxlikelihood:
            maxlikelihood = likelihood
            label = j
    im_new[i] = mus1[label]
im_new = im_new.reshape(n, m, c)
plt.imshow(im_new)
plt.show()
xs = xs.reshape(n, m, c)
plt.imshow(xs)
plt.show()

# %%
k = 50
pis = np.random.random(k)
pis /= pis.sum()
mus = np.random.random((k,c))
sigmas = np.array([np.eye(c)]*k)
xs = im/255
n, m, c = xs.shape
xs = xs.reshape(n*m, c)
# print(xs.shape)
# print(pis, mus, sigmas)

# %%
# %%time
pis1, mus1, sigmas1 = em_gmm_orig(xs, pis, mus, sigmas)

# %%
im_new = np.zeros((n*m, c))
xs = xs.reshape(n*m, c)
for i in range(n*m):
    maxlikelihood = 0
    label = 0
    for j in range(k):
        likelihood = mvn(mus[j], sigmas[j]).pdf(xs[i])
        if likelihood > maxlikelihood:
            maxlikelihood = likelihood
            label = j
    im_new[i] = mus1[label]
im_new = im_new.reshape(n, m, c)
plt.imshow(im_new)
plt.show()
xs = xs.reshape(n, m, c)
plt.imshow(xs)
plt.show()

# %%
np.random.seed(123)

# create data set
n = 1000
k = 4
_mus = np.array([[0,-4], [-2,-5], [2,1], [-3,2]])
_sigmas = np.array([[[3, 0], [0, 0.5]], [[2, 0], [0, 1.5]], [[1.2, 0], [0, 1.7]], [[1,0],[0,2]]])
_pis = np.array([0.2, 0.3, 0.2, 0.3])
xs = np.concatenate([np.random.multivariate_normal(mu, sigma, int(pi*n))
                    for pi, mu, sigma in zip(_pis, _mus, _sigmas)])
print(xs.shape)
# initial guesses for parameters
pis = np.random.random(k)
pis /= pis.sum()
mus = np.random.random((k,2))
sigmas = np.array([np.eye(2)] * k)
print(pis, mus, sigmas)

# %%
# %%time
pis1, mus1, sigmas1 = em_gmm_orig(xs, pis, mus, sigmas)
# print(ll1)
print(pis)
print(mus1)
# print(sigmas)

# %%
clusters = [[] for i in range(k)]
for i in range(n):
    maxlikelihood = 0
    label = 0
    for j in range(k):
        likelihood = mvn(mus[j], sigmas[j]).pdf(xs[i])
        if likelihood > maxlikelihood:
            maxlikelihood = likelihood
            label = j
    clusters[label].append(xs[i])
sct = []
for i in range(len(clusters)):
    sct.append(np.array(clusters[i]))

# %%
plt.scatter(sct[0][:, 0], sct[0][:, 1], c = 'red')
plt.scatter(sct[1][:, 0], sct[1][:, 1], c = 'green')
plt.scatter(sct[2][:, 0], sct[2][:, 1], c = 'blue')
plt.scatter(sct[3][:, 0], sct[3][:, 1], c = 'yellow')
plt.show()

# %%
@jit
def em_gmm_orig_r(xs, pis, mus, sigmas, tol=0.01, max_iter=100):

    n, p = xs.shape
    k = len(pis)

    ll_old = 0
    for i in range(max_iter):
        exp_A = []
        exp_B = []
        ll_new = 0

        # E-step
        ws = np.zeros((k, n))
        for j in range(len(mus)):
            for i in range(n):
                ws[j, i] = pis[j] * mvn(mus[j], sigmas[j]).pdf(xs[i])
        ws /= ws.sum(0)

        # M-step
        pis = np.zeros(k)
        for j in range(len(mus)):
            for i in range(n):
                pis[j] += ws[j, i]
        pis /= n

        mus = np.zeros((k, p))
        for j in range(k):
            for i in range(n):
                mus[j] += ws[j, i] * xs[i]
            mus[j] /= ws[j, :].sum()

        sigmas = np.zeros((k, p, p))
        for j in range(k):
            for i in range(n):
                ys = np.reshape(xs[i]- mus[j], (2,1))
                sigmas[j] += ws[j, i] * np.dot(ys, ys.T)
            sigmas[j] /= ws[j,:].sum()

        # update complete log likelihoood
        ll_new = 0.0
        for i in range(n):
            s = 0
            for j in range(k):
                s += pis[j] * mvn(mus[j], sigmas[j]).pdf(xs[i])
            ll_new += np.log(s)
#         print(ll_new)
        if np.abs(ll_new - ll_old) < tol:
            break
        ll_old = ll_new

    return ll_new, pis, mus, sigmas

# %%
np.random.seed(123)

# create data set
n = 1000
_mus = np.array([[0,4], [-2,0]])
_sigmas = np.array([[[3, 0], [0, 0.5]], [[1,0],[0,2]]])
_pis = np.array([0.6, 0.4])
xs = np.concatenate([np.random.multivariate_normal(mu, sigma, int(pi*n))
                    for pi, mu, sigma in zip(_pis, _mus, _sigmas)])

# initial guesses for parameters
pis = np.random.random(3)
pis /= pis.sum()
mus = np.random.random((3,2))
sigmas = np.array([np.eye(2)] * 3)

# %%
# %%time
ll1, pis1, mus1, sigmas = em_gmm_orig_r(xs, pis, mus, sigmas)
print(ll1)
print(pis)
print(mus1)
print(sigmas)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\numba\errors.py in new_error_context(fmt_, *args, **kwargs)
#     490     try:
# --> 491         yield
#     492     except NumbaError as e:
#
# ~\Anaconda3\lib\site-packages\numba\lowering.py in lower_block(self, block)
#     215                                    loc=self.loc, errcls_=defaulterrcls):
# --> 216                 self.lower_inst(inst)
#     217
#
# ~\Anaconda3\lib\site-packages\numba\objmode.py in lower_inst(self, inst)
#      64         if isinstance(inst, ir.Assign):
# ---> 65             value = self.lower_assign(inst)
#      66             self.storevar(value, inst.target.name)
#
# ~\Anaconda3\lib\site-packages\numba\objmode.py in lower_assign(self, inst)
#     158         elif isinstance(value, ir.Expr):
# --> 159             return self.lower_expr(value)
# ...

# %%
x, y = np.mgrid[-1:1:.01, -1:1:.01]
print(x, y)
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y
print(pos)
rv = mvn([0.5, -0.2], [[2.0, 0.3], [0.3, 0.5]])
plt.contourf(x, y, rv.pdf(pos))
